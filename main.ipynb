# %%
from utils.preProcess import *
from utils.showData.showData import *
from utils.decriptiveCal import *

# %%
pd.options.display.float_format = '{:.3f}'.format

# %%
data = pd.read_csv("All_GPUs.csv")

# Overview of data
num_data = data.shape[0];
num_features = data.shape[1];

preprocess(data)

# %%
data.describe(include='all')
# Out:
#                  Architecture  Best_Resolution_width  Best_Resolution_height  \
# count                    2625               2625.000                2625.000
# unique                    592                    NaN                     NaN
# top     Maxwell GM206-300-A1                     NaN                     NaN
# freq                       54                    NaN                     NaN
# mean                      NaN               1963.483                1108.917
# min                       NaN                640.000                 480.000
# 25%                       NaN               1600.000                 900.000
# 50%                       NaN               1920.000                1080.000
# 75%                       NaN               1920.000                1080.000
# max                       NaN               5760.000                2160.000
# std                       NaN                608.482                 305.431
#
#         Boost_Clock  Core_Speed  DVI_Connection Dedicated Direct_X  \
# count      2625.000    2625.000        2625.000      2625     2625
# unique          NaN         NaN             NaN         2       18
# top             NaN         NaN             NaN       Yes  DX 12.0
# freq            NaN         NaN             NaN      2366     1324
# mean       1204.019     954.733           1.475       NaN      NaN
# min         400.000     100.000           0.000       NaN      NaN
# 25%        1178.000     880.000           1.000       NaN      NaN
# 50%        1198.981     938.004           1.413       NaN      NaN
# 75%        1198.981    1058.000           2.000       NaN      NaN
# max        1936.000    1784.000           4.000       NaN      NaN
# std         180.324     249.542           0.620       NaN      NaN
#
#         DisplayPort_Connection  HDMI_Connection  ... ROPs_Per_Core  \
# count                 2625.000         2625.000  ...      2625.000
# unique                     NaN              NaN  ...           NaN
# top                        NaN              NaN  ...           NaN
# freq                       NaN              NaN  ...           NaN
# mean                     1.694            0.875  ...        29.357
# min                      0.000            0.000  ...         1.000
# 25%                      1.657            0.857  ...        16.000
# 50%                      1.657            1.000  ...        24.000
# 75%                      1.657            1.000  ...        32.000
# max                      4.000            3.000  ...       128.000
# std                      0.640            0.403  ...        19.450
#
#         ROPs_Cores                   Release_Date Resolution_WxH_width  \
# count     2625.000                           2625             2625.000
# unique       4.000                            NaN                  NaN
# top          1.000                            NaN                  NaN
# freq      2324.000                            NaN                  NaN
# mean           NaN  2013-01-03 05:05:00.342856960             4004.602
# min            NaN            2001-01-02 00:00:00             1280.000
# 25%            NaN            2011-05-17 00:00:00             2560.000
# 50%            NaN            2013-05-30 00:00:00             4096.000
# 75%            NaN            2015-03-13 00:00:00             4096.000
# max            NaN            2017-09-30 00:00:00             7680.000
# std            NaN                            NaN             1419.180
#
#         Resolution_WxH_height  SLI_Crossfire   Shader     TMUs  Texture_Rate  \
# count                2625.000           2625 2625.000 2625.000      2625.000
# unique                    NaN              2      NaN      NaN           NaN
# top                       NaN            Yes      NaN      NaN           NaN
# freq                      NaN           1730      NaN      NaN           NaN
# mean                 2260.616            NaN    4.790   75.743        98.638
# min                   900.000            NaN    1.000    1.000         1.000
# 25%                  1600.000            NaN    5.000   40.000        38.000
# 50%                  2160.000            NaN    5.000   64.000        62.000
# 75%                  2160.000            NaN    5.000  112.000       141.000
# max                  4320.000            NaN    5.000  384.000       717.000
# std                   771.057            NaN    0.588   52.085        89.479
#
#        VGA_Connection
# count        2625.000
# unique            NaN
# top               NaN
# freq              NaN
# mean            0.000
# min             0.000
# 25%             0.000
# 50%             0.000
# 75%             0.000
# max             0.000
# std             0.000
#
# [11 rows x 38 columns]

# %%
numerical_data = data.select_dtypes(include=[np.number]).columns
for col in numerical_data:
    Q_1 = data[col].quantile(0.25)
    Q_3 = data[col].quantile(0.75)
    IQR = Q_3 - Q_1
    lower_bound = Q_1 - 1.5 * IQR
    upper_bound = Q_3 + 1.5 * IQR
    data = data[(data[col] >= lower_bound) & (data[col] <= upper_bound)]

# %%
data.describe(include='all')
# Out:
#                  Architecture  Best_Resolution_width  Best_Resolution_height  \
# count                     435                435.000                 435.000
# unique                    160                    NaN                     NaN
# top     GCN 1.0 Pitcairn PRO                     NaN                     NaN
# freq                       19                    NaN                     NaN
# mean                      NaN               1754.092                 989.195
# min                       NaN               1280.000                 720.000
# 25%                       NaN               1600.000                 900.000
# 50%                       NaN               1920.000                1080.000
# 75%                       NaN               1920.000                1080.000
# max                       NaN               1920.000                1080.000
# std                       NaN                222.735                 124.523
#
#         Boost_Clock  Core_Speed  DVI_Connection Dedicated Direct_X  \
# count       435.000     435.000         435.000       435      435
# unique          NaN         NaN             NaN         2       12
# top             NaN         NaN             NaN       Yes  DX 12.0
# freq            NaN         NaN             NaN       372      180
# mean       1195.389     880.333           1.519       NaN      NaN
# min        1080.000     570.000           1.000       NaN      NaN
# 25%        1198.981     800.000           1.413       NaN      NaN
# 50%        1198.981     938.004           1.413       NaN      NaN
# 75%        1198.981     938.004           1.413       NaN      NaN
# max        1198.981    1150.000           2.000       NaN      NaN
# std          16.731     131.604           0.290       NaN      NaN
#
#         DisplayPort_Connection  HDMI_Connection  ... ROPs_Per_Core  \
# count                  435.000          435.000  ...       435.000
# unique                     NaN              NaN  ...           NaN
# top                        NaN              NaN  ...           NaN
# freq                       NaN              NaN  ...           NaN
# mean                     1.657            0.903  ...        21.457
# min                      1.657            0.857  ...         4.000
# 25%                      1.657            0.857  ...        16.000
# 50%                      1.657            0.857  ...        24.000
# 75%                      1.657            1.000  ...        24.000
# max                      1.657            1.000  ...        48.000
# std                      0.000            0.066  ...         8.933
#
#         ROPs_Cores                   Release_Date Resolution_WxH_width  \
# count      435.000                            435              435.000
# unique       2.000                            NaN                  NaN
# top          1.000                            NaN                  NaN
# freq       429.000                            NaN                  NaN
# mean           NaN  2011-02-01 07:20:16.551724032             3161.931
# min            NaN            2005-02-01 00:00:00             1600.000
# 25%            NaN            2010-03-30 00:00:00             2560.000
# 50%            NaN            2011-04-13 00:00:00             2560.000
# 75%            NaN            2012-06-01 00:00:00             4096.000
# max            NaN            2015-10-21 00:00:00             4096.000
# std            NaN                            NaN              779.449
#
#         Resolution_WxH_height  SLI_Crossfire  Shader    TMUs  Texture_Rate  \
# count                 435.000            435 435.000 435.000       435.000
# unique                    NaN              2     NaN     NaN           NaN
# top                       NaN             No     NaN     NaN           NaN
# freq                      NaN            239     NaN     NaN           NaN
# mean                 1819.766            NaN   4.616  48.929        47.200
# min                   900.000            NaN   3.000   8.000         2.000
# 25%                  1600.000            NaN   4.100  32.000        27.500
# 50%                  1600.000            NaN   5.000  56.000        59.000
# 75%                  2160.000            NaN   5.000  56.000        59.000
# max                  2160.000            NaN   5.000  96.000        94.000
# std                   285.961            NaN   0.600  19.755        22.500
#
#        VGA_Connection
# count         435.000
# unique            NaN
# top               NaN
# freq              NaN
# mean            0.000
# min             0.000
# 25%             0.000
# 50%             0.000
# 75%             0.000
# max             0.000
# std             0.000
#
# [11 rows x 38 columns]

# %%
data.to_csv('new_file.csv', index=False)
